# %%
from langsmith import Client

# %% [markdown]
# Add feedback to specific

# %%
RUN_ID="ba85c8b8-9ffb-4020-9bf2-da4e55b58d53"

# %%
client=Client()

# %%
client.create_feedback(
    run_id=RUN_ID,
    key="feedback",
    score=0,
    feedback_source_type="api"
)
# Out:
# Error creating feedback
# Traceback (most recent call last):
#   File "c:\Users\jaysi\Desktop\Desktop\Ai-engineering\.venv\Lib\site-packages\langsmith\utils.py", line 181, in raise_for_status_with_text
#     response.raise_for_status()
#     ~~~~~~~~~~~~~~~~~~~~~~~~~^^
#   File "c:\Users\jaysi\Desktop\Desktop\Ai-engineering\.venv\Lib\site-packages\requests\models.py", line 1167, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 403 Client Error: Forbidden for url: https://api.smith.langchain.com/feedback
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "c:\Users\jaysi\Desktop\Desktop\Ai-engineering\.venv\Lib\site-packages\langsmith\client.py", line 1835, in request_with_retries
#     ls_utils.raise_for_status_with_text(response)
#     ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^
# ...
