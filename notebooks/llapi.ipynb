# %%
from json import load
from dotenv import load_dotenv
import os
load_dotenv();

# %% [markdown]
# Google gen ai

# %%
import os
from google import genai

genai_client = genai.Client(api_key=os.getenv("GEMINI_API_KEY"))

response = genai_client.models.generate_content(
    model="gemini-2.5-flash",
    contents=[
        "You are a helpful assistant",
        "write a poem about a cat"
    ]
)

print(response.text)
print(response.usage_metadata)
# Out:
# A creature of comfort, a velvety grace,
# With whiskers that twitch on a soft furry face.
# It moves like a shadow, with paws light and neat,
# A master of silence, on soft padded feet.
#
# It stretches and yawns in a sun-dappled spot,
# A coil of warm fur, a contented soft knot.
# Then rises and arches, a graceful slow curve,
# A picture of ease, every muscle and nerve.
#
# A gleam in its eye, a twitch of its ear,
# For phantom mice rustling, or something quite near.
# A pounce on a feather, a string on the floor,
# Then a blink and a yawn, asking quietly for more.
#
# But when it decides, with a rub of its head,
# To ask for a stroke, or to sleep on your bed,
# A rumble begins, a soft motor-like hum,
# The sweetest of sounds, when its moment has come.
#
# A master of secrets, a queen or a king,
# The comfort and calm that a small cat can bring.
# So here's to the cat, with its purrs and its naps,
# Who gracefully rules all our homes and our laps.
# cache_tokens_details=None cached_content_token_count=None candidates_token_count=249 candidates_tokens_details=None prompt_token_count=12 prompt_tokens_details=[ModalityTokenCount(
#   modality=<MediaModality.TEXT: 'TEXT'>,
#   token_count=12
# )] thoughts_token_count=1329 tool_use_prompt_token_count=None tool_use_prompt_tokens_details=None total_token_count=1590 traffic_type=None
